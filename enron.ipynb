# %%
import pickle
import pandas as pd

enron_data = pickle.load(open("/Users/jerry/PycharmProjects/sayan_3/ud120-projects-master/final_project/final_project_dataset.pkl", "rb"))

# %%
df_set = pd.DataFrame(enron_data)
g =df_set.count(axis = 'index')
timezone = []
df_set
# Out:
#                                      METTS MARK BAXTER JOHN C  \
# salary                                   365788        267102
# to_messages                                 807           NaN
# deferral_payments                           NaN       1295738
# total_payments                          1061827       5634343
# loan_advances                               NaN           NaN
# bonus                                    600000       1200000
# email_address              mark.metts@enron.com           NaN
# restricted_stock_deferred                   NaN           NaN
# deferred_income                             NaN      -1386055
# total_stock_value                        585062      10623258
# expenses                                  94299         11200
# from_poi_to_this_person                      38           NaN
# exercised_stock_options                     NaN       6680544
# from_messages                                29           NaN
# ...

# %%
g =df_set.count(axis = 'index')
g
# Out:
# METTS MARK              21
# BAXTER JOHN C           21
# ELLIOTT STEVEN          21
# CORDES WILLIAM R        21
# HANNON KEVIN P          21
#                         ..
# GRAMM WENDY L           21
# CAUSEY RICHARD A        21
# TAYLOR MITCHELL S       21
# DONAHUE JR JEFFREY M    21
# GLISAN JR BEN F         21
# Length: 146, dtype: int64

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df_set, hue = 'salary', height = 8).map(plt.scatter, 's','sepal.width').add_legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salary'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-042fe577ab55> in <module>
#       1 sns.set_style('whitegrid')
# ...

# %%
salary = []
mi = []
salary.clear()
for i in enron_data:
    salary.append(enron_data[i]["salary"])
for i in range(len(salary)):
    if salary[i] == "NaN":
        salary[i] = 0
    mi.append(salary[i])

# %%
m = len(salary)
n =int(m/2)
mi.sort()
t =mi[n]
t
# Out:
# 210692

# %%
bonus = []
ni = []
bonus.clear()
for i in enron_data:
    bonus.append(enron_data[i]["bonus"])
for i in range(len(bonus)):
    if bonus[i] == "NaN":
        bonus[i] = 0 
    ni.append(bonus[i])
len(salary)
# Out:
# 146

# %%
ni.sort()
m = len(bonus)
n = int(m/2)
y =ni[n]
y
# Out:
# 300000

# %%
bonus
# Out:
# [600000,
#  1200000,
#  350000,
#  0,
#  1500000,
#  325000,
#  0,
#  2600000,
#  1150000,
#  400000,
#  0,
#  0,
#  850000,
#  700000,
#  0,
#  0,
#  1200000,
#  1100000,
#  250000,
#  0,
#  0,
#  850000,
#  3100000,
#  0,
#  0,
#  2000000,
#  0,
#  250000,
#  0,
#  1000000,
#  700000,
#  0,
#  700000,
#  0,
#  200000,
#  0,
#  1700000,
#  0,
#  0,
#  0,
#  800000,
#  1000000,
#  8000000,
#  0,
#  425000,
#  0,
#  0,
#  750000,
#  0,
#  0,
#  650000,
#  1500000,
#  200000,
#  0,
#  600000,
#  0,
#  3000000,
#  1100000,
#  0,
#  3000000,
#  100000,
#  0,
#  200000,
#  0,
#  7000000,
#  750000,
#  750000,
#  0,
#  325000,
#  509870,
#  0,
#  700000,
#  2500000,
#  0,
#  0,
#  1350000,
#  0,
#  350000,
#  0,
#  0,
#  0,
#  5249999,
#  1000000,
#  750000,
#  0,
#  1300000,
#  0,
#  1250000,
#  1750000,
#  400000,
#  0,
#  800000,
#  0,
#  0,
#  500000,
#  5600000,
#  0,
#  0,
#  0,
#  0,
#  0,
#  788750,
#  1000000,
#  97343619,
#  0,
#  325000,
#  450000,
#  0,
#  4175000,
#  600000,
# ...

# %%
timezone = []
i = 0
for i in range(len(salary)):
    if salary[i] > t:
        if bonus[i] > m:
            timezone.append(1)
        else:
            timezone.append(0)
    else:
        timezone.append(0)
len(timezone)
# Out:
# 146

# %%
for i in range(len(salary)):
    if salary[i] > 2000000:
        if bonus[i] > 1000000:
            salary.pop(i)
            bonus.pop(i)
            timezone.pop(i)
        else:
            pass
    else:
        pass

len(timezone),len(salary),len(bonus)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-111-c4e44c4cb375> in <module>
#       1 for i in range(len(salary)):
# ----> 2     if salary[i] > 1000000:
#       3         if bonus[i] > 1000000:
#       4             salary.pop(i)
#       5             bonus.pop(i)
#
# IndexError: list index out of range

# %%
df3 =pd.DataFrame({'salary':salary, 'bonus':bonus, 'good':timezone})
import seaborn as sns
import matplotlib.pyplot as plt
df3
# Out:
#      salary    bonus  good
# 0    365788   600000     1
# 1    267102  1200000     1
# 2    170941   350000     0
# 3         0        0     0
# 4    243293  1500000     1
# ..      ...      ...   ...
# 140       0        0     0
# 141  415189  1000000     1
# 142  265214   600000     1
# 143  278601   800000     1
# 144  274975   600000     1
#
# [145 rows x 3 columns]

# %%
df3.plot(kind = 'scatter', x ='salary', y = 'bonus')

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df3, hue = 'good', height = 10).map(plt.scatter, 'salary','bonus').add_legend()
plt.show()

# %%
per = (count/len(timezone))*100
per
# Out:
# 0.0

# %%
m = len(enr)
i = 0
while i < m :
    if timezone[i] > 1000000:
        if language[i] > 5000000:
            print(enr[i])
        else:
            pass
    else:
        pass
    i += 1
# Out:
# LAY KENNETH L
# SKILLING JEFFREY K
# TOTAL

# %%
len(enr)
# Out:
# 146

# %%
def get_counts(sequence):
    counts = {}
    for i in sequence:
        if i in counts:
            counts[i]+=1
        else :
            counts[i] = 1
    return counts

x = get_counts(timezone)
print(x)
# Out:
# {365788: 1, 267102: 1, 170941: 1, 0: 51, 243293: 1, 267093: 1, 370448: 1, 374125: 1, 197091: 1, 130724: 1, 248546: 1, 257486: 1, 288542: 1, 251654: 1, 288558: 1, 63744: 1, 357091: 1, 271442: 1, 304110: 1, 187922: 1, 213625: 1, 249201: 1, 231330: 1, 182245: 1, 211788: 1, 224305: 1, 273746: 1, 339288: 1, 216582: 1, 210500: 1, 272880: 1, 477: 1, 269076: 1, 428780: 1, 211844: 1, 206121: 1, 174246: 1, 510364: 1, 365038: 1, 365163: 1, 162779: 1, 236457: 1, 1072321: 1, 261516: 1, 329078: 1, 184899: 1, 192008: 1, 262663: 1, 304588: 1, 278601: 2, 199157: 1, 96840: 1, 80818: 1, 213999: 1, 262788: 1, 210692: 1, 222093: 1, 440698: 1, 240189: 1, 420636: 1, 275101: 1, 314288: 1, 94941: 1, 239502: 1, 1111258: 1, 6615: 1, 288589: 1, 404338: 1, 26704229: 1, 259996: 1, 317543: 1, 201955: 1, 248146: 1, 263413: 1, 76399: 1, 655037: 1, 261809: 1, 248017: 1, 229284: 1, 231946: 1, 221003: 1, 158403: 1, 250100: 1, 492375: 1, 1060932: 1, 261879: 1, 239671: 1, 309946: 1, 85274: 1, 247338: 1, 349487: 1, 330546
# ...

# %%
def get_count(sequence):
    count = 0
    for i in sequence:
        count +=  1
    return count

y = get_count(timezone)
print(y)

# %%
with open("/Users/jerry/PycharmProjects/sayan_3/ud120-projects-master/final_project/poi_names.txt") as file:
    records = []
    line = file.readline()
    while line:
        records.append(line)
        line = file.readline()
file.close()

# %%
print(records)

# %%
path =open("/Users/jerry/PycharmProjects/sayan_3/ud120-projects-master/final_project/poi_names.txt")
fr = path.readlines()
len(fr[2:])

# %%
enron_data["SKILLING JEFFREY K"]["exercised_stock_options"]

# %%
enr
